# %% [markdown]
# <a href="https://colab.research.google.com/github/geek4s/langchain-legal-research-tool/blob/main/langchain_legalresearchtool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langchain-groq langchain-community langchain-core langchain-text-splitters chromadb sentence-transformers PyPDF2 python-docx
print("✅ Done")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 73.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 54.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 74.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 61.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.43.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.43.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.43.0 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.43.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.43.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.43.0 which is incompatible.
# ✅ Done

# %%
import os, getpass
from pathlib import Path
from langchain_groq import ChatGroq
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_core.messages import HumanMessage
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
import PyPDF2
from docx import Document as Docx

os.environ["GROQ_API_KEY"] = getpass.getpass("Groq API key: ")

llm        = ChatGroq(model_name="llama-3.1-8b-instant", temperature=0.2)
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
splitter   = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)

CASE_LAW   = Chroma(collection_name="case_law",   embedding_function=embeddings)
COMPLIANCE = Chroma(collection_name="compliance",  embedding_function=embeddings)
REGULATORY = Chroma(collection_name="regulatory",  embedding_function=embeddings)

print("✅ Ready")
# Out:
# /tmp/ipykernel_1098/2155166659.py:4: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import Chroma
# Groq API key: ··········
# /tmp/ipykernel_1098/2155166659.py:18: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# /tmp/ipykernel_1098/2155166659.py:21: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   CASE_LAW   = Chroma(collection_name="case_law",   embedding_function=embeddings)
# ✅ Ready

# %%
docs = {
    "roe_v_wade.txt": """CASE: Roe v. Wade (1973) Citation: 410 U.S. 113
Court: Supreme Court of the United States
Decision: The Constitution protects a woman's right to privacy under the Due Process Clause.
Key Principle: Constitutional privacy rights; substantive due process.""",

    "gdpr_compliance.txt": """GDPR COMPLIANCE POLICY - Version 3.1 Effective: 2024-01-01
Data Retention: 36 months default. Financial records: 7 years.
Right to Erasure: Article 17 - deletion within 30 days of request.
Data Breach Notification: Notify supervisory authority within 72 hours (Article 33).
Penalties: Up to EUR 20 million or 4% of global annual turnover.""",

    "sec_ruling_2024.txt": """REGULATORY UPDATE - SEC Final Rule Effective: December 2023
1. Disclose material cybersecurity incidents within 4 business days.
2. Annual cybersecurity risk management disclosure required in Form 10-K.
3. Board oversight of cybersecurity risks must be documented.
Deadline: Large filers Dec 18 2023. All others June 15 2024.
Penalties: Non-disclosure subject to SEC enforcement action.""",

    "employment_discrimination.txt": """LEGAL BRIEF - Johnson v. TechCorp 2024
Claim: Wrongful termination based on race under Title VII.
Precedents: McDonnell Douglas Corp. v. Green 411 U.S. 792 (1973) burden-shifting framework.
Texas Dept. of Community Affairs v. Burdine 450 U.S. 248 (1981) employer must show legitimate reason.
Action: File EEOC charge within 300-day statute of limitations.""",
}

for name, content in docs.items():
    Path(name).write_text(content, encoding="utf-8")

print(f"✅ {len(docs)} documents created")
# Out:
# ✅ 4 documents created

# %%
def load(path: str) -> str:
    ext = Path(path).suffix.lower()
    if ext == ".pdf":
        return "\n".join(p.extract_text() or "" for p in PyPDF2.PdfReader(open(path,"rb")).pages)
    elif ext == ".docx":
        return "\n".join(p.text for p in Docx(path).paragraphs if p.text.strip())
    return Path(path).read_text(encoding="utf-8", errors="ignore")

def ingest(path: str, store: Chroma, doc_type: str, **meta):
    text  = load(path).replace('\u2013','-').replace('\u2014','-').replace('\u2019',"'")
    docs  = [Document(page_content=c, metadata={"source": path, "doc_type": doc_type, **meta})
             for c in splitter.split_text(text) if len(c) > 50]
    store.add_documents(docs)
    print(f"  ✔ {path} → {len(docs)} chunks → [{store._collection.name}]")

print("Ingesting...")
ingest("roe_v_wade.txt",               CASE_LAW,   "case_law",   jurisdiction="US Federal", year="1973")
ingest("employment_discrimination.txt", CASE_LAW,   "legal_brief",jurisdiction="US Federal", year="2024")
ingest("gdpr_compliance.txt",          COMPLIANCE,  "compliance", jurisdiction="EU",         effective_date="2024-01-01")
ingest("sec_ruling_2024.txt",          REGULATORY,  "regulatory", regulator="SEC",           effective_date="2023-12-01")
print("✅ All ingested")
# Out:
# Ingesting...
#   ✔ roe_v_wade.txt → 1 chunks → [case_law]
#   ✔ employment_discrimination.txt → 1 chunks → [case_law]
#   ✔ gdpr_compliance.txt → 1 chunks → [compliance]
#   ✔ sec_ruling_2024.txt → 1 chunks → [regulatory]
# ✅ All ingested

# %%
# ─── CELL 5: Query Prompt ─────────────────────────────────────────────────

QA_PROMPT = ChatPromptTemplate.from_template("""
You are a legal research assistant.

Use ONLY the provided context.

Cite every claim as [Source N].

Structure your response as:

Summary

Legal Analysis

Key Precedents

Caveats

Context:
{context}

Question:
{question}
""")

# %%
# ─── CELL 6: Regulatory Prompt ────────────────────────────────────────────

REG_PROMPT = ChatPromptTemplate.from_template("""
You are a compliance analyst.

For each regulatory update on "{topic}":

1. State regulation name.
2. State regulator.
3. Effective date.
4. Explain what changed.
5. Explain compliance impact.

Context:
{context}
""")

# %%
# ─── CELL 7: Legal Brief Prompt ───────────────────────────────────────────

BRIEF_PROMPT = ChatPromptTemplate.from_template("""
You are a senior attorney.

Use ONLY the provided context.

Cite every claim as [Source N].

CASE:
{case}

CLIENT POSITION:
Protect client interests and ensure regulatory compliance.

Context:
{context}
""")

# %%
# ─── CELL 8: Ingest Documents ──────────────────────────────────────────
ingest(
    "/content/legaldoc.pdf",
    CASE_LAW,
    "case_law",
    jurisdiction="US Federal",
    year="2024"
)

ingest(
    "/content/legaldoc1.docx",
    CASE_LAW,
    "case_law",
    jurisdiction="US Federal",
    year="2024"
)

print("\n✅ Both documents ingested. Now query them:")
print('  legal_assistant("your question", mode="query")')
print('  legal_assistant("your topic",    mode="regulatory")')
print('  legal_assistant("your case",     mode="brief")')
# Out:
#   ✔ /content/legaldoc.pdf → 12 chunks → [case_law]
#   ✔ /content/legaldoc1.docx → 16 chunks → [case_law]
#
# ✅ Both documents ingested. Now query them:
#   legal_assistant("your question", mode="query")
#   legal_assistant("your topic",    mode="regulatory")
#   legal_assistant("your case",     mode="brief")

# %%
# ─── CELL 9: Create Retrievers & Chains ───────────────────────────────────

# Create retrievers AFTER ingestion
case_law_retriever = CASE_LAW.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)

compliance_retriever = COMPLIANCE.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)

regulatory_retriever = REGULATORY.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)


def format_docs(docs):
    return "\n\n".join(
        f"[Source {i+1}]\n{doc.page_content}"
        for i, doc in enumerate(docs)
    )


# ---------------------- Query Chain ----------------------

query_chain = (
    {
        "context": case_law_retriever | format_docs,
        "question": RunnablePassthrough(),
    }
    | QA_PROMPT
    | llm
    | StrOutputParser()
)


# ---------------------- Regulatory Chain ----------------------

regulatory_chain = (
    {
        "context": regulatory_retriever | format_docs,
        "topic": RunnablePassthrough(),
    }
    | REG_PROMPT
    | llm
    | StrOutputParser()
)


# ---------------------- Legal Brief Chain ----------------------

brief_chain = (
    {
        "context": case_law_retriever | format_docs,
        "case": RunnablePassthrough(),
    }
    | BRIEF_PROMPT
    | llm
    | StrOutputParser()
)


def answer_legal_query(query):
    return query_chain.invoke(query)


def flag_regulatory(topic):
    return regulatory_chain.invoke(topic)


def generate_brief(case):
    return brief_chain.invoke(case)


def legal_assistant(query, mode):

    if mode == "query":
        return answer_legal_query(query)

    elif mode == "regulatory":
        return flag_regulatory(query)

    elif mode == "brief":
        return generate_brief(query)

    return "Invalid mode."

    print(f"\n{'='*60}")
    print(f"MODE : {mode.upper()}")
    print(f"INPUT: {query}")
    print(f"{'='*60}\n")

    if mode == "query":
        print(answer_legal_query(query))

    elif mode == "regulatory":
        print(flag_regulatory(query))

    elif mode == "brief":
        print(generate_brief(query))

    else:
        print("Unknown mode.")

# %%
# For legal questions and precedents
# legal_assistant("What happens if a company has a data breach?", mode="query")

# For regulatory compliance checks
# legal_assistant("What are the latest cybersecurity rules?", mode="regulatory")

# For generating a full legal brief
legal_assistant("Employee was fired because of their race.", mode="brief")
# Out:
# "Based on the provided context, I will analyze the case and provide a response as a senior attorney.\n\n**Initial Assessment**\n\nThe client, a former employee of NexaCorp Inc., claims wrongful termination based on race under Title VII. To protect the client's interests and ensure regulatory compliance, we must navigate the complex landscape of employment discrimination laws.\n\n**Key Precedents**\n\n1. **McDonnell Douglas Corp. v. Green** (1973): The burden-shifting framework will be crucial in establishing a prima facie case. [Source 1, Source 4]\n2. **Texas Dept. of Community Affairs v. Burdine** (1981): The employer must show a legitimate reason for the termination. [Source 1]\n3. **Griggs v. Duke Power Co.** (1971): The disparate impact theory may be applicable, as statistical evidence can establish a prima facie case without proving intentional discrimination. [Source 4]\n\n**Potential Strategies**\n\n1. **Disparate Impact Theory**: We can argue that NexaCorp's employment practices have a disproportionate adverse effect on the protected class, establishing a prima facie case under Griggs v. Duke Power Co. [Source 4]\n2. **Disparate Treatment Theory**: We can use the burden-shifting framework from McDonnell Douglas Corp. v. Green to establish a prima facie case, followed by evidence of intentional discrimination. [Source 1, Source 4]\n3. **Statistical Evidence**: We can use internal compensation analysis and HR manager testimony to demonstrate the disparity in treatment. [Source 5]\n\n**Potential Weaknesses**\n\n1. **Legitimate Business Reasons**: NexaCorp may argue that individual decisions were made for legitimate business reasons, which could undermine our case. [Source 5]\n2. **Wal-Mart v. Dukes**: This precedent may complicate class certification if NexaCorp argues that each hiring decision was independently made. [Source 5]\n3. **Role Differences**: Some pay disparities may be partially explained by role differences, which could weaken our case. [Source 5]\n\n**Next Steps**\n\n1. **File EEOC Charge**: We must file an EEOC charge within the 300-day statute of limitations to initiate the process. [Source 1]\n2. **Gather Evidence**: We need to collect and analyze statistical evidence, HR manager testimony, and internal compensation analysis to build a strong case.\n3. **Class Certification**: We must navigate the complexities of class certification, considering the potential impact of Wal-Mart v. Dukes.\n\n**Conclusion**\n\nThe case against NexaCorp Inc. is complex and multifaceted. To protect the client's interests and ensure regulatory compliance, we must carefully navigate the precedents, potential strategies, and weaknesses. A thorough analysis of the evidence and a well-crafted legal strategy will be essential in achieving a successful outcome."

# %%
# !pip install -q gradio

# %%
import gradio as gr

with gr.Blocks(theme=gr.themes.Soft(), title="AI Legal Research Assistant") as demo:

    gr.Markdown(
        """
        # ⚖️ AI Legal Research Assistant

        Ask legal questions using your LangChain RAG system.
        """
    )

    mode = gr.Dropdown(
        choices=["query", "regulatory", "brief"],
        value="query",
        label="Mode"
    )

    question = gr.Textbox(
        lines=8,
        placeholder="Enter your legal question...",
        label="Legal Query"
    )

    answer = gr.Markdown(label="Generated Response")


    submit = gr.Button("Generate Answer")

    submit.click(
        fn=legal_assistant,
        inputs=[question, mode],
        outputs=answer
    )

demo.launch(share=True)
# Out:
# /tmp/ipykernel_1098/2069730903.py:3: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft(), title="AI Legal Research Assistant") as demo:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://99db250577fc071047.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://99db250577fc071047.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
